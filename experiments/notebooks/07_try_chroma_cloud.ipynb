# %%
import chromadb

client = chromadb.CloudClient(
  api_key='ck-6DGWYstPRU5ws1zaMbyBHGZAsYTmUQMeFB3XC4hzr2rx',
  tenant='c6af326e-6de4-4331-b43a-7d7a5812a0e5',
  database='madetech_handbook'
)

# %%
client.list_collections()
# Out:
# []
